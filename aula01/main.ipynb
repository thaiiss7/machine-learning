# %%
a = "hello world!!"

# %%
print(a)
# Out:
# hello world!!

# %%
import numpy as np 
import pandas as pd
import os


lista = []

import os
for dirname, _, filenames in os.walk('data'):
    for filename in filenames:
        lista.append(os.path.join(dirname, filename))

# %%
dfs = [pd.read_csv(item) for item in lista]

df = pd.concat(dfs)

# %%
df
# Out:
#                             Film  Year          Script Type  \
# 0                            300  2007           adaptation
# 1                   3:10 to Yuma  2007               remake
# 2               30 Days of Night  2007           adaptation
# 3            Across the Universe  2007  original screenplay
# 4   Alien vs. Predator - Requiem  2007               sequel
# ..                           ...   ...                  ...
# 87                     Uncharted  2022                  NaN
# 88                     Vengeance  2022                  NaN
# 89                 Violent Night  2022                  NaN
# 90       Where the Crawdads Sing  2022                  NaN
# 91                             X  2022                  NaN
#
#    Rotten Tomatoes  critics Metacritic  critics Average critics   \
# 0                        60                  51               56
# 1                        88                  76               82
# 2                        50                  53               52
# 3                        54                  56               55
# 4                        14                  29               22
# ..                      ...                 ...              ...
# 87                       41                  45               43
# 88                       81                  65               73
# 89                       73                  55               64
# 90                       35                  43               39
# 91                       94                  79               87
#
#     Rotten Tomatoes Audience  Metacritic Audience   \
# 0                        89.0                   71
# 1                        86.0                   73
# 2                        56.0                   65
# 3                        82.0                   73
# 4                        31.0                   45
# ..                        ...                  ...
# 87                       90.0                   62
# 88                       86.0                   64
# 89                       88.0                   66
# 90                       96.0                   65
# 91                       75.0                   66
#
#    Rotten Tomatoes vs Metacritic  deviance Average audience   ...  \
# 0                                       18                80  ...
# 1                                       13                80  ...
# 2                                       -9                61  ...
# 3                                        9                78  ...
# 4                                      -14                38  ...
# ..                                     ...               ...  ...
# 87                                      28                76  ...
# 88                                      22                75  ...
# 89                                      22                77  ...
# 90                                      31                81  ...
# 91                                       9                71  ...
#
#    financial source, if not The numbers                    Genres  \
# 0                                   NaN                       NaN
# 1                                   NaN                       NaN
# 2                                   NaN                       NaN
# 3                                   NaN                       NaN
# 4                                   NaN                       NaN
# ..                                  ...                       ...
# 87                                  NaN                 adventure
# 88                                  NaN  music, mystery, thriller
# 89                                  NaN                   holiday
# 90                                  NaN  drama, mystery, thriller
# 91                                  NaN         mystery, thriller
#
#    Opening Weekend ($)  % of Gross earned abroad Budget recovered  \
# 0                  NaN                       NaN              NaN
# 1                  NaN                       NaN              NaN
# 2                  NaN                       NaN              NaN
# 3                  NaN                       NaN              NaN
# 4                  NaN                       NaN              NaN
# ..                 ...                       ...              ...
# 87            44010155                    62.90%          333.91%
# 88             1755325                     2.32%                -
# 89            13450240                    34.65%          383.00%
# 90            17253227                    33.92%          568.91%
# 91             4275126                    22.12%         1511.31%
#
#    Budget recovered opening weekend  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 87                           36.68%
# 88                                -
# 89                           67.25%
# 90                           71.89%
# 91                          427.51%
#
#    Film list here: https://www.boxofficemojo.com/year/2019/?ref_=bo_yl_table_5  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
#
#    Film list here: https://www.boxofficemojo.com/year/2020/?grossesOption=calendarGrosses  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
#
#    Film list here: https://www.boxofficemojo.com/year/2021/  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
#
#    film list here https://www.boxofficemojo.com/year/2022/
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
#
# [1967 rows x 43 columns]

# %%
df = df[['Year', 'Script Type', 'Rotten Tomatoes  critics', 'Metacritic Audience ','Metacritic critics', 'Average audience ', 'Worldwide Gross ($million)', 'Budget ($million)', 'Primary Genre' ]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = df[['Year', 'Script Type', 'Rotten Tomatoes  critics', 'Metacritic Audience ','Metacritic critics', 'Average audience ', 'Worldwide Gross ($million)', 'Budget ($million)', 'Primary Genre' ]]
#
# File c:\Users\disrct\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\disrct\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File c:\Users\disrct\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Metacritic critics'] not in index"

# %%
df
# Out:
#     Year          Script Type Rotten Tomatoes  critics Metacritic Audience   \
# 0   2007           adaptation                       60                   71
# 1   2007               remake                       88                   73
# 2   2007           adaptation                       50                   65
# 3   2007  original screenplay                       54                   73
# 4   2007               sequel                       14                   45
# ..   ...                  ...                      ...                  ...
# 87  2022                  NaN                       41                   62
# 88  2022                  NaN                       81                   64
# 89  2022                  NaN                       73                   66
# 90  2022                  NaN                       35                   65
# 91  2022                  NaN                       94                   66
#
#    Average audience  Worldwide Gross ($million) Budget ($million)  \
# 0                 80                        456                65
# 1                 80                         70                50
# 2                 61                         75                32
# 3                 78                         29                45
# 4                 38                        129                40
# ..               ...                        ...               ...
# 87                76                      400.7             120.0
# 88                75                        4.4                 -
# 89                77                       76.6              20.0
# 90                81                      136.5              24.0
# 91                71                       15.1               1.0
#
#    Primary Genre
# 0         action
# 1        western
# 2         horror
# 3        musical
# 4         sci-fi
# ..           ...
# 87        action
# 88        comedy
# 89        action
# 90       romance
# 91        horror
#
# [1967 rows x 8 columns]

# %%
df['Script Type'].unique()
# Out:
# array(['adaptation', 'remake', 'original screenplay', 'sequel',
#        'based on a true story', 'documentary', 'sequel, adaptation',
#        'remake / reboot', 'remake / reboot, adaptation', 'sequel ',
#        'based on a true story ', 'adaptation, remake / reboot',
#        'original screenplay ', 'based on a true story, adaptation',
#        'prequel', 'adaptation, based on a true story',
#        'adaptation, sequel', 'semi-sequel',
#        'based on a true story, remake', nan], dtype=object)

# %%
col = df.columns.get_loc('Script Type')

df['Script Type'] = df['Script Type'].fillna('unknown')

for i in range(len(df)):
    value = df.iloc[i, col]

    if 'original screenplay' in value:
        value = 'original'
    elif 'sequel ' in value:
        value = 'sequel'
    elif 'true story' in value or 'true story' in value:
        value = 'real'
    elif 'remake' in value:
        value = 'remake'
    elif 'adaptation' in value:
        value = 'adaptation'
    elif 'prequel' in value:
        value = 'prequel'
    else:
        value = 'unknown'

    df.iloc[i, col] = value

df['Script Type'].unique()
# Out:
# C:\Users\disrct\AppData\Local\Temp\ipykernel_19296\725325619.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Script Type'] = df['Script Type'].fillna('unknown')
# array(['adaptation', 'remake', 'original', 'unknown', 'real', 'sequel',
#        'prequel'], dtype=object)

# %%
df['Rotten Tomatoes  critics'].value_counts()
# Out:
# Rotten Tomatoes  critics
# 85    30
# 94    29
# 93    29
# 83    28
# 92    28
#       ..
# 52     1
# 1      1
# 13     1
# 33     1
# 27     1
# Name: count, Length: 190, dtype: int64

# %%
df.isna().sum()
# Out:
# Year                             0
# Script Type                      0
# Rotten Tomatoes  critics         1
# Metacritic Audience              0
# Average audience                 1
# Worldwide Gross ($million)       0
# Budget ($million)                0
# Primary Genre                 1689
# dtype: int64

# %%
coluna ='Rotten Tomatoes  critics'
df = df[df[coluna] != '-']
df[coluna].dropna(inplace=True)

df[coluna] = pd.to_numeric(df[coluna])

df[coluna].unique()
# Out:
# C:\Users\disrct\AppData\Local\Temp\ipykernel_19296\288302972.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[coluna].dropna(inplace=True)
# C:\Users\disrct\AppData\Local\Temp\ipykernel_19296\288302972.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[coluna] = pd.to_numeric(df[coluna])
# array([ 60.,  88.,  50.,  54.,  14.,  26.,  80.,  52.,  71.,  69.,  82.,
#          1.,  67.,  27.,  93.,   2.,  23.,  35.,  28.,   3.,  92.,   4.,
#         15.,  45.,  13.,  43.,  94.,  91.,   8.,  79.,  66.,  90.,  56.,
#         36.,  63.,  49.,  31.,  29.,  95.,  39.,   9.,  70.,  21.,  11.,
#         97.,  20.,  18.,  47.,  42.,  61.,  87.,  78.,  86.,  41.,  30.,
#         19.,  72.,  33.,  57.,  46.,  55.,  89.,  75.,  96.,  64.,  77.,
#         73.,  40.,  38.,  83.,  16.,  51.,  25.,  58.,  53.,  62.,   7.,
#         34.,  24.,  32.,  48.,   5.,  85.,  65.,  68.,  22.,  37.,   0.,
#         81.,  59.,  44.,  98.,  84.,  12.,  74.,  17.,   6.,  99.,  10.,
#         76.,  nan, 100.])

# %%
coluna ='Average audience '
df = df[df[coluna] != '-']
df[coluna].dropna(inplace=True)

df[coluna] = pd.to_numeric(df[coluna])

df[coluna].unique()
# Out:
# array([80. , 61. , 78. , 38. , 60. , 81. , 59. , 57. , 69. , 71. , 29. ,
#        79. , 24. , 82. , 25. , 50. , 58. , 43. , 49. , 84. , 35. , 45. ,
#        70. , 53. , 86. , 75. , 74. , 56. , 76. , 62. , 64. , 48. , 42. ,
#        67. , 87. , 72. , 83. , 68. , 66. , 44. , 77. , 89. , 65. , 63. ,
#        55. , 93. , 46. , 40. , 51. , 73. , 52. , 39. , 41. , 54. , 88. ,
#        30. , 47. , 22. , 85. , 31. , 36. , 91. , 90. , 33. , 27. , 32. ,
#        34. , 92. , 37. , 23. ,  7. , 66.5, 90.5, 85.5, 64.5, 77.5, 74.5,
#        59.5, 79.5, 55.5, 63.5, 48.5, 69.5, 82.5, 73.5, 58.5, 40.5, 57.5,
#        41.5, 72.5, 54.5, 47.5, 62.5, 80.5, 65.5, 67.5, 70.5, 75.5, 32.5,
#        56.5, 81.5, 71.5, 33.5, 76.5, 86.5, 15.5, 52.5, 78.5, 46.5, 18.5,
#        60.5, 51.5, 43.5, 61.5, 28. , 19. ,  nan,  5. ])

# %%
coluna = 'Primary Genre'
df[coluna] = df[coluna].fillna('unknown')
df[coluna].value_counts()
# Out:
# Primary Genre
# unknown      1682
# action         68
# drama          52
# comedy         43
# adventure      24
# thriller       21
# horror         20
# crime          13
# biography       8
# animation       6
# romance         6
# musical         3
# fantasy         3
# western         2
# sci-fi          2
# mystery         1
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Primary Genre'] = le.fit_transform(df['Primary Genre'])

le2 = LabelEncoder()
df['Script Type'] = le2.fit_transform(df['Script Type'])

df
# Out:
#     Year  Script Type  Rotten Tomatoes  critics Metacritic Audience   \
# 0   2007            0                      60.0                   71
# 1   2007           15                      88.0                   73
# 2   2007            8                      50.0                   65
# 3   2007            9                      54.0                   73
# 4   2007           12                      14.0                   45
# ..   ...          ...                       ...                  ...
# 87  2022            0                      41.0                   62
# 88  2022            4                      81.0                   64
# 89  2022            0                      73.0                   66
# 90  2022           11                      35.0                   65
# 91  2022            8                      94.0                   66
#
#     Average audience  Worldwide Gross ($million) Budget ($million)  \
# 0                80.0                        456                65
# 1                80.0                         70                50
# 2                61.0                         75                32
# 3                78.0                         29                45
# 4                38.0                        129                40
# ..                ...                        ...               ...
# 87               76.0                      400.7             120.0
# 88               75.0                        4.4                 -
# 89               77.0                       76.6              20.0
# 90               81.0                      136.5              24.0
# 91               71.0                       15.1               1.0
#
#     Primary Genre
# 0               0
# 1              15
# 2               8
# 3               9
# 4              12
# ..            ...
# 87              0
# 88              4
# 89              0
# 90             11
# 91              8
#
# [1954 rows x 8 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.hist(df["Year"])
plt.xlabel("Year")
plt.ylabel("movies")
# Out:
# Text(0, 0.5, 'movies')

# %%
df.boxplot(column = ['Rotten Tomatoes  critics', 'Metacritic  critics', 'Average audience '])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.boxplot(column = ['Rotten Tomatoes  critics', 'Metacritic  critics', 'Average audience '])
#
# File c:\Users\disrct\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_core.py:533, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     516 @Substitution(data="", backend=_backend_doc)
#     517 @Appender(_boxplot_doc)
#     518 def boxplot_frame(
#    (...)
#     530     **kwargs,
#     531 ):
#     532     plot_backend = _get_plot_backend(backend)
# --> 533     return plot_backend.boxplot_frame(
#     534         self,
#     535         column=column,
#     536         by=by,
#     537         ax=ax,
#     538         fontsize=fontsize,
#     539         rot=rot,
#     540         grid=grid,
#     541         figsize=figsize,
#     542         layout=layout,
#     543         return_type=return_type,
#     544         **kwargs,
#     545     )
#
# File c:\Users\disrct\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:495, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     480 def boxplot_frame(
#     481     self,
#     482     column=None,
#    (...)
#     491     **kwds,
#     492 ):
#     493     import matplotlib.pyplot as plt
# --> 495     ax = boxplot(
#     496         self,
#     497         column=column,
#     498         by=by,
#     499         ax=ax,
#     500         fontsize=fontsize,
#     501         grid=grid,
#     502         rot=rot,
#     503         figsize=figsize,
#     504         layout=layout,
#     505         return_type=return_type,
#     506         **kwds,
#     507     )
#     508     plt.draw_if_interactive()
#     509     return ax
#
# File c:\Users\disrct\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:472, in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     470     columns = data.columns
#     471 else:
# --> 472     data = data[columns]
#     474 result = plot_group(columns, data.values.T, ax, **kwds)
#     475 ax.grid(grid)
#
# File c:\Users\disrct\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\disrct\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File c:\Users\disrct\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6261, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6259 if nmissing:
#    6260     if nmissing == len(indexer):
# -> 6261         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6264     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Rotten Tomatoes  critics', 'Metacritic  critics', 'Average audience '], dtype='object')] are in the [columns]"

# %%
df[ df['Worldwide Gross ($million)'] < 2000].plot.scatter(x = 'Average audience ', y = 'Worldwide Gross ($million)', s = 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df[ df['Worldwide Gross ($million)'] < 2000].plot.scatter(x = 'Average audience ', y = 'Worldwide Gross ($million)', s = 3)
#
# File c:\Users\disrct\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\disrct\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File c:\Users\disrct\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6130, in Series._cmp_method(self, other, op)
#    6127 lvalues = self._values
#    6128 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6130 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6132 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\disrct\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File c:\Users\disrct\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# File pandas/_libs/ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'
